# %%
import pandas as pd

# %%
df = pd.read_csv('OECD-wellbeing-OECD-wellbeing.csv')

# %%
for column in df.columns:
    print(df[column].unique(),len(df[column].unique()))
print(len(df))
# Out:
# ['DNK' 'ITA' 'NLD' 'DEU' 'FRA' 'GRC' 'BEL' 'CZE' 'ESP' 'POL' 'PRT' 'LUX'
#  'LTU' 'EST' 'HUN' 'LVA' 'SWE' 'FIN' 'GBR' 'CHE' 'AUT' 'NOR' 'IRL' 'ISL'
#  'SVK' 'SVN' 'ROU' 'HRV' 'BGR' 'JPN' 'CHL' 'NZL' 'CAN' 'USA' 'KOR' 'ISR'
#  'MEX' 'TUR' 'AUS' 'CRI' 'COL' 'ARG' 'THA' 'BRA' 'PER' 'ZAF' 'IDN'] 47
# ['Denmark' 'Italy' 'Netherlands' 'Germany' 'France' 'Greece' 'Belgium'
#  'Czechia' 'Spain' 'Poland' 'Portugal' 'Luxembourg' 'Lithuania' 'Estonia'
#  'Hungary' 'Latvia' 'Sweden' 'Finland' 'United Kingdom' 'Switzerland'
#  'Austria' 'Norway' 'Ireland' 'Iceland' 'Slovak Republic' 'Slovenia'
#  'Romania' 'Croatia' 'Bulgaria' 'Japan' 'Chile' 'New Zealand' 'Canada'
#  'United States' 'Korea' 'Israel' 'Mexico' 'Türkiye' 'Australia'
#  'Costa Rica' 'Colombia' 'Argentina' 'Thailand' 'Brazil' 'Peru'
#  'South Africa' 'Indonesia'] 47
# ['Access to green space' 'Adult literacy skills' 'Adult numeracy skills'
#  'Adults with low literacy skills' 'Adults with low numeracy skills'
# ...

# %%
df.head()
# Out:
#   REF_AREA      Country                Measure UNIT_MEASURE  \
# 0      DNK      Denmark  Access to green space   PT_POP_URB
# 1      ITA        Italy  Access to green space   PT_POP_URB
# 2      NLD  Netherlands  Access to green space   PT_POP_URB
# 3      DEU      Germany  Access to green space   PT_POP_URB
# 4      FRA       France  Access to green space   PT_POP_URB
#
#                   Unit of measure    Age    Sex Education  \
# 0  Percentage of urban population  Total  Total     Total
# 1  Percentage of urban population  Total  Total     Total
# 2  Percentage of urban population  Total  Total     Total
# 3  Percentage of urban population  Total  Total     Total
# 4  Percentage of urban population  Total  Total     Total
#
#                   Domain  Year  OBS_VALUE
# 0  Environmental quality  2018  59.497138
# 1  Environmental quality  2018  61.231153
# 2  Environmental quality  2018  78.205338
# 3  Environmental quality  2018  67.472499
# ...

# %%
dfned = df.loc[df['REF_AREA']=='NLD',:]
print(len(dfned)/69)
dfned.loc[dfned['Domain'] == 'Subjective well-being',:].['Measure'].unique()
#for column in dfned.columns:
#    print(dfned[column].unique(),len(dfned[column].unique()))
# Out:
# 37.42028985507246
# array(['Feelings of physical pain', 'Life satisfaction',
#        'Life satisfaction score less than 5', 'Negative affect balance',
#        'Top life satisfaction scores quintile'], dtype=object)
